# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
zr=pd.read_csv('C:\\Users\\Meghana\\Downloads\\zomato_dataset.csv')

# %%
zr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123657 entries, 0 to 123656
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Restaurant Name  123657 non-null  object
#  1   Dining Rating    91421 non-null   float64
#  2   Delivery Rating  122377 non-null  float64
#  3   Dining Votes     123657 non-null  int64
#  4   Delivery Votes   123657 non-null  int64
#  5   Cuisine          123657 non-null  object
#  6   Place Name       123657 non-null  object
#  7   City             123657 non-null  object
#  8   Item Name        123657 non-null  object
#  9   Best Seller      27942 non-null   object
#  10  Votes            123657 non-null  int64
#  11  Prices           123657 non-null  float64
#  12  Total Rating     91360 non-null   float64
#  13  Total Votes      123657 non-null  int64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 13.2+ MB

# %%
res=sns.barplot(zr['Dining Rating'],zr['Delivery Rating'])
plt.show()
# Out:
# C:\Users\Meghana\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
res = sns.barplot(x='Dining Votes',y='Delivery Votes',data=zr)
plt.show()

# %%
sns.distplot(zr.Votes,bins=10,color='g')
# Out:
# C:\Users\Meghana\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Votes', ylabel='Density'>

# %%
sns.heatmap(zr.corr(),cbar=True,Linewidths=0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 sns.heatmap(zr.corr(),cbar=True,Linewidths=0.5)
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\matrix.py:553, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     551 if square:
# ...

# %%
sns.pairplot(zr,hue='Restaurant Name',palette='Set1')
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 sns.pairplot(zr,hue='Restaurant Name',palette='Set1')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\axisgrid.py:2130, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2128     diag_kws.setdefault("fill", True)
# ...

# %%
zr.head()
# Out:
#   Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 0      Doner King            3.9              4.2            39
# 1      Doner King            3.9              4.2            39
# 2      Doner King            3.9              4.2            39
# 3      Doner King            3.9              4.2            39
# 4      Doner King            3.9              4.2            39
#
#    Delivery Votes   Cuisine  Place Name        City                 Item Name  \
# 0               0  Fast Food   Malakpet   Hyderabad       Platter Kebab Combo
# 1               0  Fast Food   Malakpet   Hyderabad   Chicken Rumali Shawarma
# 2               0  Fast Food   Malakpet   Hyderabad    Chicken Tandoori Salad
# 3               0  Fast Food   Malakpet   Hyderabad         Chicken BBQ Salad
# 4               0  Fast Food   Malakpet   Hyderabad  Special Doner Wrap Combo
#
#   Best Seller  Votes  Prices  Total Rating  Total Votes
# ...

# %%
sns.catplot(x="Place Name",y='Prices',data=zr)

# %%
sns.catplot(x="Place Name",y='Prices',data=zr,kind='box')

# %%
sns.catplot(data=zr,kind="box")

# %%
sns.catplot(x="Restaurant Name",y='Votes',data=zr,hue='Place Name',kind="bar")

# %%
sns.jointplot(x='Total Votes',y='Prices',data=zr)

# %%
sns.jointplot(x='Total Rating',y='Prices',data=zr,kind='hex',color='b')

# %%
sns.jointplot(x='Total Rating',y='Prices',data=zr,kind='kde',color='orange')

# %%
sns.pairplot(zr)

# %%
sns.pairplot(zr,hue='City')

# %%
sns.pairplot(zr,vars=["Prices","Votes"])

# %%
sns.pairplot(zr,vars=["Dining Rating","Delivery Rating"])

# %%
sns.heatmap(zr.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(zr.corr(),annot=True,cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
name= zr['Restaurant Name']
vo=zr['Total Rating']
plt.pie(vo,labels=name,autopct="%1.2f%%",colors=['c','b','m','pink'],shadow=True,startangle=140)
plt.title("POPULARITY ")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 name= zr['Restaurant Name']
#       2 vo=zr['Total Rating']
# ----> 3 plt.pie(vo,labels=name,autopct="%1.2f%%",colors=['c','b','m','pink'],shadow=True,startangle=140)
#       4 plt.title("POPULARITY ")
#       5 plt.show()
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2744, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2737 @_copy_docstring_and_deprecators(Axes.pie)
#    2738 def pie(
#    2739         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2742         textprops=None, center=(0, 0), frame=False,
#    2743         rotatelabels=False, *, normalize=True, data=None):
# -> 2744     return gca().pie(
# ...

# %%
zr['Restaurant Name']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 zr.sort_values['Restaurant Name']
#
# TypeError: 'method' object is not subscriptable

# %%
zr.sort_values('Restaurant Name')
# Out:
#                 Restaurant Name  Dining Rating  Delivery Rating  Dining Votes  \
# 60216              12 To 12 BBQ            4.0              4.0           104
# 60157              12 To 12 BBQ            4.0              4.0           104
# 60156              12 To 12 BBQ            4.0              4.0           104
# 60155              12 To 12 BBQ            4.0              4.0           104
# 60154              12 To 12 BBQ            4.0              4.0           104
# ...                         ...            ...              ...           ...
# 6309   Zomoz - The Momo Company            NaN              4.3             0
# 6308   Zomoz - The Momo Company            NaN              4.3             0
# 6307   Zomoz - The Momo Company            NaN              4.3             0
# 6314   Zomoz - The Momo Company            NaN              4.3             0
# 6311   Zomoz - The Momo Company            NaN              4.3             0
#
# ...

# %%
zr['Restaurant Name'].value_counts()
# Out:
# McDonald's                        2059
# Domino's Pizza                    1435
# Burger King                       1352
# FreshMenu                         1097
# Pizza Hut                         1077
#                                   ...
# Akbar Fast Food                      5
# Al - Hamoor Arabian Restaurant       5
# Sukanta                              4
# Evoke                                4
# Asian Bowls By Zahvi                 4
# Name: Restaurant Name, Length: 826, dtype: int64

# %%
Names=["McDonald's","Domino's Pizza","Burger King","FreshMenu","Pizza Hut"]
votes=[685,684,765,664,576]
plt.pie(votes,labels=Names,colors=['c','b','m','pink','orange'],autopct="% 1.2f%%",
        explode=(0,0.2,0,0,0),shadow=True)
plt.show()
plt.savefig('Piechartpp.png')
# taking the dtaset ref seeing how popular some famous retaraunts are.
